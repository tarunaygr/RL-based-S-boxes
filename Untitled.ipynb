# %%
from cmath import inf
from cv2 import threshold
import Auxiliary.s_box as sbox
import os
from random import random,randint,choice
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import Auxiliary.funcs_filtered_outputs_m_3 as m3
import numpy as np
#from keras.models import Sequential
import keras
#from keras.layers import Dense
from tensorflow.keras import Sequential
from tensorflow.keras.layers import  Flatten, Dense

NUM_RULES=3
INPUT_SIZE=8
OUTPUT_SIZE=8

def convert(state):
    converted=np.zeros((NUM_RULES*56),dtype=np.int8)
    for i,j in enumerate(state):
        converted[i*56+j]=1
    return converted

def convert_8(state):
    r=np.where(state==1)[0]
    res=[s%56 for s in r]
    return res

rules_list,rule_names=m3.return_rules()

model = Sequential()
model.add(Dense(56*NUM_RULES, input_shape=(56*NUM_RULES,),batch_size=1,name='inputlayer'))
model.add(Dense(56, activation='relu',name='hiddenlayer'))
model.add(Dense(1, activation='relu',name='outputlayer'))
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
# model.summary()
average_reward=0
beta=0.1
epsilon_threshold=0.4
alpha=0.05
gamma=.8
# rules=[m3.rule_178,m3.rule_92,m3.rule_154,m3.rule_18,m3.rule_68,m3.rule_172,m3.rule_222,m3.rule_46]
S=[29, 53,52]
A_val=randint(0,55)
while(A_val in S):
    A_val=randint(0,55)
A=(randint(0,NUM_RULES-1),A_val)
print(f'Initial State: {[rule_names[s] for s in S]}')
while True:

    print(f"Replacing {rule_names[S[A[0]]]} with {rule_names[A[1]]}...")
    
    S_prime=S.copy()
    S_prime[A[0]]=A[1]
    print(f'Current State: {[rule_names[s] for s in S_prime]}')
    R=sbox.state_crypto_strength(S_prime)
    epsilon = random()
    if epsilon<epsilon_threshold:
        print("Exploring...")
        rand_action=randint(0,55)
        while(rand_action in S_prime):
            rand_action=randint(0,55)
        A_prime=(randint(0,NUM_RULES-1),rand_action)
        taken_state=S_prime.copy()
        taken_state[A_prime[0]]=A_prime[1]
        taken_state=convert(taken_state)
    else:
        print("Exploiting...")
        max_states=[]
        max_actions=[]
        max_value=-inf
        # for i in range(8):
        #     for j in range(56):
        #         if j in S_prime:
        #             continue
        #         next_state=np.zeros((8*56),dtype=np.int8)
        #         for k in S_prime:
        #             if k==S_prime[i]:
        #                 continue
        #             next_state[i*56+k]=1
        #         next_state[i*56+j]=1
        
        for i in range(NUM_RULES):
            current_action=S_prime[i]
            
            for j in range(56):
                if j==current_action:
                    continue
                next_state=convert(S_prime)
                next_state[i*56+current_action]=0
                next_state[i*56+j]=1
                # print('input')
                # print(np.array([np.array(next_state).flatten()]))
                prediction=model.predict(np.array([next_state]))
                # print("prediction")
                # print(prediction)
                if prediction>max_value:
                    max_value=prediction
                    max_states=[next_state]
                    max_actions=[(i,j)]
                elif prediction==max_value:
                    max_states.append(next_state)
                    max_actions.append((i,j))
        action_index=randint(0,len(max_actions)-1)
        taken_state=max_states[action_index]
        A_prime=max_actions[action_index]
    # print("State")
    # print(taken_state)
    Q_s_a=model.predict(np.array([convert(S_prime)]))+sbox.state_crypto_strength(S_prime)
    Q_sprime_aprime=model.predict(np.array([taken_state]))+sbox.state_crypto_strength(convert_8(taken_state))
    target=Q_s_a+alpha*(R-average_reward+gamma*(Q_sprime_aprime)-Q_s_a)
    # print(np.array([target]))
    # print(np.array([convert(S_prime)]))
    model.fit(np.array([convert(S_prime)])
                ,np.array([target]))
    delta=R-average_reward+Q_sprime_aprime-Q_s_a
    average_reward+=beta*delta
    S=S_prime
    A=A_prime
# Out:
# Using TensorFlow backend.
# C:\Users\aniru\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Initial State: ['rule_154', 'rule_178', 'rule_24']
# Replacing rule_24 with rule_238...
# Current State: ['rule_154', 'rule_178', 'rule_238']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 253ms/step - loss: 4895.7529 - mae: 69.9697
# Replacing rule_238 with rule_72...
# Current State: ['rule_154', 'rule_178', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 0s/step - loss: 4622.3589 - mae: 67.9879
# Replacing rule_178 with rule_116...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 787.5293 - mae: 28.0630
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 5ms/step - loss: 4793.2593 - mae: 69.2334
# Replacing rule_108 with rule_144...
# Current State: ['rule_144', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 4758.9019 - mae: 68.9848
# Replacing rule_144 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4499.2241 - mae: 67.0763
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 742.8871 - mae: 27.2560
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4469.4995 - mae: 66.8543
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 732.0809 - mae: 27.0570
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4445.4136 - mae: 66.6739
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 635.7712 - mae: 25.2145
# Replacing rule_116 with rule_12...
# Current State: ['rule_154', 'rule_12', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 639.7094 - mae: 25.2925
# Replacing rule_12 with rule_116...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 638.5766 - mae: 25.2701
# Replacing rule_72 with rule_12...
# Current State: ['rule_154', 'rule_116', 'rule_12']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 642.0767 - mae: 25.3392
# Replacing rule_12 with rule_72...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 639.8872 - mae: 25.2960
# Replacing rule_72 with rule_34...
# Current State: ['rule_154', 'rule_116', 'rule_34']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 4ms/step - loss: 645.3067 - mae: 25.4029
# Replacing rule_34 with rule_72...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 730.4371 - mae: 27.0266
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4661.9790 - mae: 68.2787
# Replacing rule_72 with rule_216...
# Current State: ['rule_108', 'rule_116', 'rule_216']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4648.1069 - mae: 68.1770
# Replacing rule_216 with rule_72...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 4ms/step - loss: 4398.2754 - mae: 66.3195
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 705.9636 - mae: 26.5700
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 4605.6133 - mae: 67.8647
# Replacing rule_108 with rule_40...
# Current State: ['rule_40', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 16.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4623.0640 - mae: 67.9931
# Replacing rule_72 with rule_10...
# Current State: ['rule_40', 'rule_116', 'rule_10']
# 8
# Hello
# DU = 16.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 16.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 5489.3447 - mae: 74.0901
# Replacing rule_40 with rule_166...
# Current State: ['rule_166', 'rule_116', 'rule_10']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4562.3311 - mae: 67.5450
# Replacing rule_166 with rule_120...
# Current State: ['rule_120', 'rule_116', 'rule_10']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4329.2739 - mae: 65.7972
# Replacing rule_10 with rule_238...
# Current State: ['rule_120', 'rule_116', 'rule_238']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 681.6115 - mae: 26.1077
# Replacing rule_120 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_238']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4553.0762 - mae: 67.4765
# Replacing rule_238 with rule_72...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4314.3535 - mae: 65.6837
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 8ms/step - loss: 676.1149 - mae: 26.0022
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 0s/step - loss: 4318.9209 - mae: 65.7185
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 677.8545 - mae: 26.0356
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 8ms/step - loss: 4316.7852 - mae: 65.7022
# Replacing rule_108 with rule_166...
# Current State: ['rule_166', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 682.3928 - mae: 26.1226
# Replacing rule_166 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 9ms/step - loss: 4325.0454 - mae: 65.7651
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 8ms/step - loss: 593.4250 - mae: 24.3603
# Replacing rule_72 with rule_192...
# Current State: ['rule_154', 'rule_116', 'rule_192']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 8ms/step - loss: 683.3935 - mae: 26.1418
# Replacing rule_154 with rule_78...
# Current State: ['rule_78', 'rule_116', 'rule_192']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 4567.8633 - mae: 67.5860
# Replacing rule_192 with rule_46...
# Current State: ['rule_78', 'rule_116', 'rule_46']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 4546.8545 - mae: 67.4304
# Replacing rule_116 with rule_30...
# Current State: ['rule_78', 'rule_30', 'rule_46']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 16.0 NL=96.0
# 1/1 [==============================] - 0s 8ms/step - loss: 4657.8574 - mae: 68.2485
# Replacing rule_46 with rule_40...
# Current State: ['rule_78', 'rule_30', 'rule_40']
# 8
# Hello
# DU = 16.0 NL=96.0
# Exploring...
# 8
# Hello
# DU = 16.0 NL=96.0
# 8
# Hello
# DU = 16.0 NL=96.0
# 1/1 [==============================] - 0s 0s/step - loss: 7888.2578 - mae: 88.8159
# Replacing rule_78 with rule_58...
# Current State: ['rule_58', 'rule_30', 'rule_40']
# 8
# Hello
# DU = 16.0 NL=96.0
# Exploring...
# 8
# Hello
# DU = 16.0 NL=96.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 7718.7417 - mae: 87.8564
# Replacing rule_40 with rule_72...
# Current State: ['rule_58', 'rule_30', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 8ms/step - loss: 4486.2515 - mae: 66.9795
# Replacing rule_58 with rule_246...
# Current State: ['rule_246', 'rule_30', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 8ms/step - loss: 4490.4111 - mae: 67.0105
# Replacing rule_30 with rule_116...
# Current State: ['rule_246', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 7ms/step - loss: 4481.5298 - mae: 66.9442
# Replacing rule_246 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 2ms/step - loss: 4244.4658 - mae: 65.1496
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 651.9645 - mae: 25.5336
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4260.8350 - mae: 65.2751
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 657.8094 - mae: 25.6478
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4273.8286 - mae: 65.3745
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 656.4960 - mae: 25.6222
# Replacing rule_116 with rule_80...
# Current State: ['rule_154', 'rule_80', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 4502.3042 - mae: 67.0992
# Replacing rule_154 with rule_180...
# Current State: ['rule_180', 'rule_80', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4301.5952 - mae: 65.5865
# Replacing rule_80 with rule_116...
# Current State: ['rule_180', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 667.8428 - mae: 25.8427
# Replacing rule_180 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 5ms/step - loss: 4490.8813 - mae: 67.0140
# Replacing rule_72 with rule_136...
# Current State: ['rule_108', 'rule_116', 'rule_136']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4519.2310 - mae: 67.2252
# Replacing rule_136 with rule_72...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4470.9688 - mae: 66.8653
# Replacing rule_116 with rule_210...
# Current State: ['rule_108', 'rule_210', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4506.7437 - mae: 67.1323
# Replacing rule_210 with rule_116...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4252.8208 - mae: 65.2137
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 655.4560 - mae: 25.6019
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4465.8843 - mae: 66.8273
# Replacing rule_116 with rule_246...
# Current State: ['rule_108', 'rule_246', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4510.0625 - mae: 67.1570
# Replacing rule_246 with rule_116...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 643.8676 - mae: 25.3745
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4215.6523 - mae: 64.9281
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 645.6227 - mae: 25.4091
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4220.2031 - mae: 64.9631
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=96.0
# 1/1 [==============================] - 0s 3ms/step - loss: 646.1895 - mae: 25.4203
# Replacing rule_154 with rule_126...
# Current State: ['rule_126', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=96.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=96.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 6595.8125 - mae: 81.2146
# Replacing rule_126 with rule_78...
# Current State: ['rule_78', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 4526.8999 - mae: 67.2822
# Replacing rule_78 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4321.9990 - mae: 65.7419
# Replacing rule_72 with rule_78...
# Current State: ['rule_108', 'rule_116', 'rule_78']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4539.4072 - mae: 67.3751
# Replacing rule_78 with rule_72...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4167.7686 - mae: 64.5583
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 627.9863 - mae: 25.0597
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4173.8599 - mae: 64.6054
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 596.7944 - mae: 24.4294
# Replacing rule_154 with rule_198...
# Current State: ['rule_198', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4535.8823 - mae: 67.3490
# Replacing rule_198 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4163.7642 - mae: 64.5272
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 628.2708 - mae: 25.0653
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4165.9790 - mae: 64.5444
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 629.8265 - mae: 25.0963
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4165.8047 - mae: 64.5430
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 630.5842 - mae: 25.1114
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 13ms/step - loss: 4163.6255 - mae: 64.5262
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 8ms/step - loss: 630.6681 - mae: 25.1131
# Replacing rule_154 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=96.0
# 1/1 [==============================] - 0s 16ms/step - loss: 4345.6592 - mae: 65.9216
# Replacing rule_108 with rule_36...
# Current State: ['rule_36', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=96.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=96.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 0s/step - loss: 6324.1484 - mae: 79.5245
# Replacing rule_72 with rule_154...
# Current State: ['rule_36', 'rule_116', 'rule_154']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=96.0
# 1/1 [==============================] - 0s 4ms/step - loss: 4715.0571 - mae: 68.6663
# Replacing rule_154 with rule_72...
# Current State: ['rule_36', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=96.0
# Exploring...
# 8
# Hello
# DU = 32.0 NL=96.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 6469.7837 - mae: 80.4350
# Replacing rule_36 with rule_250...
# Current State: ['rule_250', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4509.3340 - mae: 67.1516
# Replacing rule_250 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 4069.8447 - mae: 63.7953
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 0s/step - loss: 476.0691 - mae: 21.8190
# Replacing rule_154 with rule_132...
# Current State: ['rule_132', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploiting...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 4ms/step - loss: 669.5500 - mae: 25.8757
# Replacing rule_132 with rule_108...
# Current State: ['rule_108', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploiting...
# 8
# Hello
# DU = 32.0 NL=64.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 5ms/step - loss: 4085.6492 - mae: 63.9191
# Replacing rule_108 with rule_154...
# Current State: ['rule_154', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 3ms/step - loss: 476.2732 - mae: 21.8237
# Replacing rule_154 with rule_86...
# Current State: ['rule_86', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 64.0 NL=0.0
# 1/1 [==============================] - 0s 0s/step - loss: 538.7133 - mae: 23.2102
# Replacing rule_86 with rule_68...
# Current State: ['rule_68', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 64.0 NL=0.0
# Exploring...
# 8
# Hello
# DU = 64.0 NL=0.0
# 8
# Hello
# DU = 32.0 NL=64.0
# 1/1 [==============================] - 0s 3ms/step - loss: 637.6288 - mae: 25.2513
# Replacing rule_68 with rule_40...
# Current State: ['rule_40', 'rule_116', 'rule_72']
# 8
# Hello
# DU = 32.0 NL=64.0
# Exploring...
# 8
# Hello
